# %%
from sqlalchemy import create_engine

# %%
# engine = create_engine('postgresql://user@localhost:5432/mydb')

# engine = create_engine('postgresql://user:password@localhost:5432//sql_challenge')

# I think I have an issue with my 'user' for postgreSQL and 'password'. Need to consult to a TA about this matter.

engine = create_engine('postgresql+psycopg2://postgres:5432@localhost/sql_challenge')

# %%
# connection = engine.connect()

# %%
import pandas as pd

# %%
a=pd.read_sql_query('select * from salaries',con=engine)

# %%
a
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
a['salary'].plot.hist()

# %%
b=pd.read_sql_query('select * from question_1',con=engine)
b.head()
# Out:
#    emp_no last_name first_name sex  salary
# 0   57444      Babb      Berry   F   48973
# 1   13616     Lorho      Perry   F   40000
# 2  240129    Karnin      Roddy   M   43548
# 3  427958    Poujol   Feixiong   F   63377
# 4   35916    Talmon     Wonhee   F   40000

# %%
c=pd.read_sql_query('select * from question_8',con=engine)
c.head()
# Out:
#   last_name  last_name_counts
# 0      Baba               226
# 1     Coorg               223
# 2    Gelosh               223
# 3    Farris               222
# 4   Sudbeck               222
